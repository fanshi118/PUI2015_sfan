# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(100)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
a = np.random.randn(100,2)

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
b = 2.5*np.random.randn(50,2)+5

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
print a
# Out:
# [[-1.74976547  0.3426804 ]
#  [ 1.1530358  -0.25243604]
#  [ 0.98132079  0.51421884]
#  [ 0.22117967 -1.07004333]
#  [-0.18949583  0.25500144]
#  [-0.45802699  0.43516349]
#  [-0.58359505  0.81684707]
#  [ 0.67272081 -0.10441114]
#  [-0.53128038  1.02973269]
#  [-0.43813562 -1.11831825]
#  [ 1.61898166  1.54160517]
#  [-0.25187914 -0.84243574]
#  [ 0.18451869  0.9370822 ]
#  [ 0.73100034  1.36155613]
#  [-0.32623806  0.05567601]
#  [ 0.22239961 -1.443217  ]
#  [-0.75635231  0.81645401]
#  [ 0.75044476 -0.45594693]
#  [ 1.18962227 -1.69061683]
#  [-1.35639905 -1.23243451]
#  [-0.54443916 -0.66817174]
#  [ 0.00731456 -0.61293874]
#  [ 1.29974807 -1.73309562]
#  [-0.9833101   0.35750775]
#  [-1.6135785   1.47071387]
#  [-1.1880176  -0.54974619]
#  [-0.94004616 -0.82793236]
#  [ 0.10886347  0.50780959]
#  [-0.86222735  1.24946974]
#  [-0.07961125 -0.88973148]
#  [-0.88179839  0.01863895]
#  [ 0.23784462  0.01354855]
#  [-1.6355294  -1.04420988]
#  [ 0.61303888  0.73620521]
#  [ 1.02692144 -1.43219061]
#  [-1.8411883   0.36609323]
#  [-0.33177714 -0.68921798]
#  [ 2.03460756 -0.55071441]
#  [ 0.75045333 -1.30699234]
#  [ 0.58057334 -1.10452309]
#  [ 0.69012147  0.68689007]
#  [-1.56668753  0.90497412]
#  [ 0.7788224   0.42823287]
#  [ 0.10887199  0.02828363]
#  [-0.57882582 -1.1994512 ]
#  [-1.70595201  0.36916396]
#  [ 1.87657343 -0.37690335]
#  [ 1.83193608  0.00301743]
#  [-0.07602347  0.00395759]
#  [-0.18501411 -2.48715154]
#  [-1.70465121 -1.13626101]
#  [-2.97331547  0.03331728]
#  [-0.24888867 -0.45017644]
#  [ 0.1324278   0.02221393]
#  [ 0.31736798 -0.75241418]
#  [-1.29639181  0.09513944]
#  [-0.4237151  -1.18598356]
#  [-0.36546199 -1.27102304]
#  [ 1.58617094  0.69339066]
#  [-1.95808123 -0.13480131]
#  [-1.54061602  2.04671397]
#  [-1.39699934 -1.09717198]
#  [-0.23871287 -1.4290669 ]
#  [ 0.94900478 -0.01939759]
#  [ 0.89459771  0.75969312]
#  [-1.49772038 -1.19388598]
#  [ 1.29626259  0.95227563]
#  [-1.21725413 -0.15726517]
#  [-1.50758516  0.10788413]
#  [ 0.74705566  0.42967644]
#  [-1.41504292 -0.64075992]
#  [ 0.7796263  -0.43812092]
#  [ 2.07479317 -0.34329768]
#  [-0.61662937  0.76318365]
#  [ 0.19291719 -0.34845893]
#  [ 2.29865394 -0.16520955]
#  [ 0.46629937  0.26998724]
#  [-0.31983105 -1.1477416 ]
#  [ 1.70362399 -0.72215077]
#  [ 1.09368665 -0.22951775]
#  [-0.00889866 -0.54319801]
#  [ 0.75306219 -1.6094389 ]
#  [ 1.94326226 -1.44743611]
#  [ 0.13024846  0.94936086]
#  [-2.01518872 -0.07954059]
#  [ 0.30104946 -1.68489996]
#  [ 0.22239081 -0.68492174]
#  [-0.12620118  1.99027365]
#  [ 0.5229978  -0.0163454 ]
#  [-0.41581634 -1.35850294]
#  [-0.51442989 -0.21606012]
#  [ 0.42238022 -1.09404293]
#  [ 1.23690789 -0.23028468]
#  [-0.7044182  -0.59137512]
#  [ 0.73699517  0.43586725]
#  [ 1.77599359  0.51307438]
#  [ 1.17052698  2.07771223]
#  [-0.45592202  0.64917293]
#  [-0.17478155  1.01726434]
#  [-0.59998304  1.57616672]]

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
scatter1 = pl.scatter(a[:,0],a[:,1],color='blue')
scatter2 = pl.scatter(b[:,0],b[:,1],color='red')
#print np.mean(a)
#print np.mean(b)
#print np.std(a)
#print np.std(b)
pl.legend([scatter1,scatter2],
          ['mean='+"%.2f"%np.mean(a)+' std='+"%.2f"%np.std(a),
           'mean='+"%.2f"%np.mean(b)+' std='+"%.2f"%np.std(b)],loc=2)

# %%
pl.show()
